# %% [markdown]
# ## Importando variáveis de ambiente
# Esse notebook prevê a existência de 2 variáveis de ambiente no arquivo .env desse projeto:
# - DATA_FOLDER
# - DATASET_FOLDER

# %%
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path=".env")

DATA_FOLDER = os.getenv("DATA_FOLDER")
DATASET_FOLDER = os.getenv("DATASET_FOLDER")

# %% [markdown]
# ## Bibliotecas Utilizadas

# %%
import random
from pathlib import Path
from torchvision import transforms
from PIL import Image
from tqdm import tqdm

# %% [markdown]
# ## Variáveis de configuração

# %%
SOURCE_DIR = DATASET_FOLDER
OUTPUT_DIR = os.path.join(DATA_FOLDER, 'splits')

TRAIN_SPLIT = 0.7
VAL_SPLIT = 0.15
TEST_SPLIT = 0.15

AUG_PER_IMAGE = 3 # Quantas versões aumentadas (augmentations) por imagem

# %% [markdown]
# ## Definindo as transform para augmentation offline

# %%
augmentation_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    
    transforms.RandomApply([
        transforms.RandomAffine(
            degrees=25,
            translate=(0.10, 0.10),   # deslocamento leve
            scale=(0.95, 1.05),       # zoom leve
            shear=10
        )
    ], p=0.8),

    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.15),

    transforms.RandomPerspective(distortion_scale=0.2, p=0.5),

    transforms.ColorJitter(
        brightness=0.4,
        contrast=0.4,
        saturation=0.4,
        hue=0.05
    ),

    transforms.GaussianBlur(kernel_size=5, sigma=(0.1, 2.0)),
    transforms.RandomAdjustSharpness(sharpness_factor=2, p=0.3),
    transforms.RandomAutocontrast(p=0.3),
])

# Transformação base (sem aumento)
basic_transform = transforms.Resize((224, 224))

# %% [markdown]
# ## Funções para salvar as imagens e processá-las (split e augmentation)

# %%
def save_image(img: Image.Image, path: Path):
    path.parent.mkdir(parents=True, exist_ok=True)
    img.save(path)

def process_class(class_path: Path):
    images = list(class_path.glob("*.jpg")) + list(class_path.glob("*.png"))
    random.shuffle(images)
    class_name = class_path.name

    n_total = len(images)
    n_train = int(n_total * TRAIN_SPLIT)
    n_val = int(n_total * VAL_SPLIT)

    splits = {
        "train": images[:n_train],
        "val": images[n_train:n_train + n_val],
        "test": images[n_train + n_val:],
    }

    for split_name, split_images in splits.items():
        for img_path in tqdm(split_images, desc=f"{class_name} - {split_name}"):
            img = Image.open(img_path).convert("RGB")

            # Salva versão sem augmentation
            out_path = OUTPUT_DIR / split_name / class_name / img_path.name
            save_image(basic_transform(img), out_path)

            # Gera imagens aumentadas apenas para o split de treino
            if split_name == "train":
                for i in range(AUG_PER_IMAGE):
                    aug_img = augmentation_transform(img)
                    aug_name = img_path.stem + f"_aug{i}.jpg"
                    out_aug_path = OUTPUT_DIR / split_name / class_name / aug_name
                    save_image(aug_img, out_aug_path)

# %% [markdown]
# ## Execução

# %%
classes = [p for p in SOURCE_DIR.iterdir() if p.is_dir()]
for cls_path in classes:
    process_class(cls_path)
# Out:
# Gobio gobio - train: 100%|██████████| 159/159 [00:07<00:00, 21.28it/s]
# Gobio gobio - val: 100%|██████████| 34/34 [00:00<00:00, 280.26it/s]
# Gobio gobio - test: 100%|██████████| 35/35 [00:00<00:00, 282.38it/s]
# Gasterosteus aculeatus - train: 100%|██████████| 40/40 [00:02<00:00, 19.03it/s]
# Gasterosteus aculeatus - val: 100%|██████████| 8/8 [00:00<00:00, 266.03it/s]
# Gasterosteus aculeatus - test: 100%|██████████| 10/10 [00:00<00:00, 336.02it/s]
# Neogobius fluviatilis - train: 100%|██████████| 71/71 [00:03<00:00, 21.48it/s]
# Neogobius fluviatilis - val: 100%|██████████| 15/15 [00:00<00:00, 335.28it/s]
# Neogobius fluviatilis - test: 100%|██████████| 16/16 [00:00<00:00, 314.44it/s]
# Barbus barbus - train: 100%|██████████| 235/235 [00:12<00:00, 19.27it/s]
# Barbus barbus - val: 100%|██████████| 50/50 [00:00<00:00, 207.50it/s]
# Barbus barbus - test: 100%|██████████| 51/51 [00:00<00:00, 224.70it/s]
# Neogobius melanostomus - train: 100%|██████████| 170/170 [00:08<00:00, 20.53it/s]
# Neogobius melanostomus - val: 100%|██████████| 36/36 [00:00<00:00, 145.08it/s]
# Neogobius melanostomus - test: 100%|██████████| 38/38 [00:00<00:00, 142.81it/s]
# Esox lucius - train: 100%|██████████| 217/217 [00:13<00:00, 16.16it/s]
# Esox lucius - val: 100%|██████████| 46/46 [00:00<00:00, 178.82it/s]
# Esox lucius - test: 100%|██████████| 48/48 [00:00<00:00, 206.71it/s]
# Silurus glanis - train: 100%|██████████| 190/190 [00:10<00:00, 18.41it/s]
# Silurus glanis - val: 100%|██████████| 40/40 [00:00<00:00, 201.47it/s]
# Silurus glanis - test: 100%|██████████| 42/42 [00:00<00:00, 190.76it/s]
# Acipenseridae - train: 100%|██████████| 205/205 [00:10<00:00, 18.85it/s]
# Acipenseridae - val: 100%|██████████| 43/43 [00:00<00:00, 173.51it/s]
# Acipenseridae - test: 100%|██████████| 45/45 [00:00<00:00, 206.62it/s]
# Vimba vimba - train: 100%|██████████| 49/49 [00:03<00:00, 15.94it/s]
# Vimba vimba - val: 100%|██████████| 10/10 [00:00<00:00, 245.94it/s]
# Vimba vimba - test: 100%|██████████| 12/12 [00:00<00:00, 198.16it/s]
# Sander lucioperca - train: 100%|██████████| 211/211 [00:11<00:00, 17.73it/s]
# Sander lucioperca - val: 100%|██████████| 45/45 [00:00<00:00, 177.40it/s]
# Sander lucioperca - test: 100%|██████████| 46/46 [00:00<00:00, 177.88it/s]
# Perca fluviatilis - train: 100%|██████████| 173/173 [00:10<00:00, 16.45it/s]
# Perca fluviatilis - val: 100%|██████████| 37/37 [00:00<00:00, 129.62it/s]
# Perca fluviatilis - test: 100%|██████████| 38/38 [00:00<00:00, 130.26it/s]
# Scardinius erythrophthalmus - train: 100%|██████████| 217/217 [00:13<00:00, 16.37it/s]
# Scardinius erythrophthalmus - val: 100%|██████████| 46/46 [00:00<00:00, 78.36it/s]
# Scardinius erythrophthalmus - test: 100%|██████████| 48/48 [00:00<00:00, 126.77it/s]
# Leuciscus cephalus - train: 100%|██████████| 197/197 [00:11<00:00, 17.51it/s]
# Leuciscus cephalus - val: 100%|██████████| 42/42 [00:00<00:00, 133.42it/s]
# Leuciscus cephalus - test: 100%|██████████| 43/43 [00:00<00:00, 82.69it/s]
# Aspius aspius - train: 100%|██████████| 240/240 [00:14<00:00, 16.67it/s]
# Aspius aspius - val: 100%|██████████| 51/51 [00:00<00:00, 151.93it/s]
# Aspius aspius - test: 100%|██████████| 52/52 [00:00<00:00, 160.27it/s]
# Abramis brama - train: 100%|██████████| 189/189 [00:11<00:00, 16.14it/s]
# Abramis brama - val: 100%|██████████| 40/40 [00:00<00:00, 149.84it/s]
# Abramis brama - test: 100%|██████████| 42/42 [00:00<00:00, 143.88it/s]
# Gymnocephalus cernuus - train: 100%|██████████| 165/165 [00:09<00:00, 18.10it/s]
# Gymnocephalus cernuus - val: 100%|██████████| 35/35 [00:00<00:00, 122.15it/s]
# Gymnocephalus cernuus - test: 100%|██████████| 36/36 [00:00<00:00, 163.10it/s]
# Tinca tinca - train: 100%|██████████| 221/221 [00:11<00:00, 18.90it/s]
# Tinca tinca - val: 100%|██████████| 47/47 [00:00<00:00, 172.00it/s]
# Tinca tinca - test: 100%|██████████| 48/48 [00:00<00:00, 201.99it/s]
# Salmo trutta subsp. fario - train: 100%|██████████| 189/189 [00:09<00:00, 20.56it/s]
# Salmo trutta subsp. fario - val: 100%|██████████| 40/40 [00:00<00:00, 157.87it/s]
# Salmo trutta subsp. fario - test: 100%|██████████| 41/41 [00:00<00:00, 172.71it/s]
# Blicca bjoerkna - train: 100%|██████████| 170/170 [00:08<00:00, 19.69it/s]
# Blicca bjoerkna - val: 100%|██████████| 36/36 [00:00<00:00, 208.89it/s]
# Blicca bjoerkna - test: 100%|██████████| 38/38 [00:00<00:00, 204.74it/s]
# Lepomis gibbosus - train: 100%|██████████| 173/173 [00:09<00:00, 18.58it/s]
# Lepomis gibbosus - val: 100%|██████████| 37/37 [00:00<00:00, 181.93it/s]
# Lepomis gibbosus - test: 100%|██████████| 38/38 [00:00<00:00, 243.60it/s]
# Anguilla anguilla - train: 100%|██████████| 186/186 [00:10<00:00, 18.32it/s]
# Anguilla anguilla - val: 100%|██████████| 39/39 [00:00<00:00, 181.47it/s]
# Anguilla anguilla - test: 100%|██████████| 41/41 [00:00<00:00, 158.24it/s]
# Cyprinus carpio - train: 100%|██████████| 412/412 [00:22<00:00, 18.31it/s]
# Cyprinus carpio - val: 100%|██████████| 88/88 [00:00<00:00, 107.99it/s]
# Cyprinus carpio - test: 100%|██████████| 89/89 [00:00<00:00, 94.27it/s]
# Carassius carassius - train: 100%|██████████| 169/169 [00:08<00:00, 19.32it/s]
# Carassius carassius - val: 100%|██████████| 36/36 [00:00<00:00, 159.05it/s]
# Carassius carassius - test: 100%|██████████| 37/37 [00:00<00:00, 177.90it/s]
# Carassius gibelio - train: 100%|██████████| 181/181 [00:09<00:00, 18.67it/s]
# Carassius gibelio - val: 100%|██████████| 38/38 [00:00<00:00, 193.55it/s]
# Carassius gibelio - test: 100%|██████████| 40/40 [00:00<00:00, 201.35it/s]
# Rhodeus amarus - train: 100%|██████████| 25/25 [00:01<00:00, 17.29it/s]
# Rhodeus amarus - val: 100%|██████████| 5/5 [00:00<00:00, 237.64it/s]
# Rhodeus amarus - test: 100%|██████████| 6/6 [00:00<00:00, 321.91it/s]
# Neogobius kessleri - train: 100%|██████████| 65/65 [00:03<00:00, 21.54it/s]
# Neogobius kessleri - val: 100%|██████████| 13/13 [00:00<00:00, 318.64it/s]
# Neogobius kessleri - test: 100%|██████████| 15/15 [00:00<00:00, 184.41it/s]
# Ctenopharyngodon idella - train: 100%|██████████| 205/205 [00:10<00:00, 19.22it/s]
# Ctenopharyngodon idella - val: 100%|██████████| 43/43 [00:00<00:00, 97.28it/s]
# Ctenopharyngodon idella - test: 100%|██████████| 45/45 [00:00<00:00, 147.46it/s]
# Rutilus rutilus - train: 100%|██████████| 222/222 [00:11<00:00, 19.59it/s]
# Rutilus rutilus - val: 100%|██████████| 47/47 [00:00<00:00, 199.01it/s]
# Rutilus rutilus - test: 100%|██████████| 49/49 [00:00<00:00, 219.94it/s]
# Leuciscus leuciscus - train: 100%|██████████| 46/46 [00:02<00:00, 20.14it/s]
# Leuciscus leuciscus - val: 100%|██████████| 9/9 [00:00<00:00, 187.41it/s]
# Leuciscus leuciscus - test: 100%|██████████| 11/11 [00:00<00:00, 158.18it/s]
# Leuciscus idus - train: 100%|██████████| 233/233 [00:11<00:00, 19.80it/s]
# Leuciscus idus - val: 100%|██████████| 50/50 [00:00<00:00, 176.05it/s]
# Leuciscus idus - test: 100%|██████████| 51/51 [00:00<00:00, 213.41it/s]
